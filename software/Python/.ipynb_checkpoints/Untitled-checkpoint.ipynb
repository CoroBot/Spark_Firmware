# %%
import hid
import time

# %%
for d in hid.enumerate():
    keys = d.keys()
    keys.sort()
    for key in keys:
        print "%s : %s" % (key, d[key])
    print ""
# Out:
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col03#7&303833b7&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 136
# usage_page : 65468
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col04#7&303833b7&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_00#7&aa4a1b9&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col01#7&16f0fc4&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col01#7&19329c09&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col02#7&19329c09&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#atk4002#3&34245a86&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 0
# product_string :
# release_number : 1
# serial_number :
# usage : 12
# usage_page : 1
# vendor_id : 0
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col03#7&19329c09&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col04#7&19329c09&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col02#7&16f0fc4&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col05#7&19329c09&0&0004#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col06#7&19329c09&0&0005#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col01#6&6589fcf&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 4
# usage_page : 13
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col01#7&34bafa79&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 1118
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col02#6&6589fcf&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col02#7&34bafa79&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col01#7&303833b7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col02#7&303833b7&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_00#7&10e3bcb7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : Cypress Semiconductor
# path : \\?\hid#vid_04b4&pid_f139&mi_00#7&2b02392a&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 61753
# product_string : KitBridge
# release_number : 523
# serial_number : 1A0F172A03254400
# usage : 1
# usage_page : 65440
# vendor_id : 1204
#
# interface_number : -1
# manufacturer_string : CoroWare Robotics Solutions
# path : \\?\hid#vid_2bd6&pid_ff02#6&3aa58adb&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 65282
# product_string : CoroBot Spark
# release_number : 1
# serial_number : 15080F3503274400
# usage : 1
# usage_page : 65280
# vendor_id : 11222
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col03#7&303833b7&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 136
# usage_page : 65468
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col04#7&303833b7&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_00#7&aa4a1b9&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col01#7&16f0fc4&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col01#7&19329c09&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col02#7&19329c09&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#atk4002#3&34245a86&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 0
# product_string :
# release_number : 1
# serial_number :
# usage : 12
# usage_page : 1
# vendor_id : 0
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col03#7&19329c09&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col04#7&19329c09&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col02#7&16f0fc4&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col05#7&19329c09&0&0004#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col06#7&19329c09&0&0005#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col01#6&6589fcf&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 4
# usage_page : 13
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col01#7&34bafa79&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 1118
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col02#6&6589fcf&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col02#7&34bafa79&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col01#7&303833b7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col02#7&303833b7&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_00#7&10e3bcb7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : Cypress Semiconductor
# path : \\?\hid#vid_04b4&pid_f139&mi_00#7&2b02392a&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 61753
# product_string : KitBridge
# release_number : 523
# serial_number : 1A0F172A03254400
# usage : 1
# usage_page : 65440
# vendor_id : 1204
#
# interface_number : -1
# manufacturer_string : CoroWare Robotics Solutions
# path : \\?\hid#vid_2bd6&pid_ff02#6&3aa58adb&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 65282
# product_string : CoroBot Spark
# release_number : 1
# serial_number : 15080F3503274400
# usage : 1
# usage_page : 65280
# vendor_id : 11222
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col03#7&303833b7&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 136
# usage_page : 65468
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col04#7&303833b7&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_00#7&aa4a1b9&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col01#7&16f0fc4&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col01#7&19329c09&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col02#7&19329c09&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 128
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#atk4002#3&34245a86&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 0
# product_string :
# release_number : 1
# serial_number :
# usage : 12
# usage_page : 1
# vendor_id : 0
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col03#7&19329c09&0&0002#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col04#7&19329c09&0&0003#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 2
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_02&col02#7&16f0fc4&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 65280
# usage_page : 65280
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col05#7&19329c09&0&0004#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 1
# usage_page : 65281
# vendor_id : 2821
#
# interface_number : 1
# manufacturer_string : ASUS
# path : \\?\hid#vid_0b05&pid_17fd&mi_01&col06#7&19329c09&0&0005#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 6141
# product_string : ASUS ROG Macrokey
# release_number : 35
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 2821
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col01#6&6589fcf&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 4
# usage_page : 13
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col01#7&34bafa79&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 2
# usage_page : 1
# vendor_id : 1118
#
# interface_number : -1
# manufacturer_string :
# path : \\?\hid#vid_0457&pid_10c6&col02#6&6589fcf&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 4294
# product_string :
# release_number : 256
# serial_number :
# usage : 1
# usage_page : 65280
# vendor_id : 1111
#
# interface_number : 1
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_01&col02#7&34bafa79&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col01#7&303833b7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 2
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_02&col02#7&303833b7&0&0001#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 1
# usage_page : 12
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string :
# path : \\?\hid#vid_045e&pid_07b2&mi_00#7&10e3bcb7&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 1970
# product_string :
# release_number : 1798
# serial_number :
# usage : 6
# usage_page : 1
# vendor_id : 1118
#
# interface_number : 0
# manufacturer_string : Cypress Semiconductor
# path : \\?\hid#vid_04b4&pid_f139&mi_00#7&2b02392a&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 61753
# product_string : KitBridge
# release_number : 523
# serial_number : 1A0F172A03254400
# usage : 1
# usage_page : 65440
# vendor_id : 1204
#
# interface_number : -1
# manufacturer_string : CoroWare Robotics Solutions
# path : \\?\hid#vid_2bd6&pid_ff02#6&3aa58adb&0&0000#{4d1e55b2-f16f-11cf-88cb-001111000030}
# product_id : 65282
# product_string : CoroBot Spark
# release_number : 1
# serial_number : 15080F3503274400
# usage : 1
# usage_page : 65280
# vendor_id : 11222

# %%
def do_me():
    try:
        print "Opening device"
        h = hid.device()
        h.open(0x2bd6, 0xff02)
        #h.open(0x1941, 0x8021) # Fine Offset USB Weather Station

        print "Manufacturer: %s" % h.get_manufacturer_string()
        print "Product: %s" % h.get_product_string()
        print "Serial No: %s" % h.get_serial_number_string()

        # try non-blocking mode by uncommenting the next line
        #h.set_nonblocking(1)

        # try writing some data to the device
    #    for k in range(10):
    #        for i in [0, 1]:
    #            for j in [0, 1]:
    #                h.write([0x80, i, j])
    #                d = h.read(5)
    #                if d:
    #                    print d
    #                time.sleep(0.05)

        print "Closing device"
        h.close()

    except IOError, ex:
        print ex
        print "You probably don't have the hard coded test hid. Update the hid.device line"
        print "in this script with one from the enumeration list output above and try again."

    print "Done"
do_me()
# Out:
# Opening device
# Manufacturer: CoroWare Robotics SolutionsOpening device
# Manufacturer: CoroWare Robotics Solutions
# Product: CoroBot Spark
# Serial No: 15080F3503274400
# Closing device
# Done
# Opening device
# Manufacturer: CoroWare Robotics Solutions
# Product: CoroBot Spark
# Serial No: 15080F3503274400
# Closing device
# Done
#
# Product: CoroBot Spark
# Serial No: 15080F3503274400
# Closing device
# Done

# %%
h=hid.device()
h.open(0x2bd6, 0xff02)

# %%
h.get_manufacturer_string()
# Out:
# u'CoroWare Robotics Solutions'
# u'CoroWare Robotics Solutions'
# u'CoroWare Robotics Solutions'
